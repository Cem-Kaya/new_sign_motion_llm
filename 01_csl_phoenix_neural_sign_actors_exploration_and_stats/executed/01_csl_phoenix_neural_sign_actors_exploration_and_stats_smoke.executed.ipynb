# %% [markdown]
# # CSL / PHOENIX / Neural Sign Actors Exploration & Statistics
#
# This notebook mirrors the local `01_how2sign_subset_exploration_and_stats.ipynb` workflow for the newer SOKE data folders:
#
# - `DATA/SOKE_DATA/CSL-Daily-Fittings`
# - `DATA/SOKE_DATA/phoenix_poses`
# - `DATA/SOKE_DATA/Neural-Sign-Actors`
#
# It summarizes split sizes, clip/frame counts, pose-file schemas, sample records, and writes reproducible CSV/plot artifacts under `new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/`.

# %%
from pathlib import Path
import gzip
import importlib.util
import json
import os
import pickle
import random
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# WSL CUDA reliability guard: keep CUDA stubs visible before importing torch.
if Path('/usr/lib/wsl/lib').exists():
    _wsl_cuda_lib = '/usr/lib/wsl/lib'
    _ld = os.environ.get('LD_LIBRARY_PATH', '')
    _parts = [p for p in _ld.split(':') if p]
    if _wsl_cuda_lib not in _parts:
        os.environ['LD_LIBRARY_PATH'] = f"{_wsl_cuda_lib}:{_ld}" if _ld else _wsl_cuda_lib
        print(f'Prepended WSL CUDA loader path: {_wsl_cuda_lib}')

TORCH_AVAILABLE = importlib.util.find_spec('torch') is not None
if TORCH_AVAILABLE:
    import torch
    print(f'Torch available: {torch.__version__}')
    print(f'CUDA available: {torch.cuda.is_available()}')
    if torch.cuda.is_available():
        print(f'CUDA device: {torch.cuda.get_device_name(torch.cuda.current_device())}')
else:
    print('Torch is not installed in this kernel. Torch is only needed for .pt stats or optional rendering.')

plt.style.use('seaborn-v0_8-whitegrid')
RNG_SEED = int(os.environ.get('NEW_DATA_RNG_SEED', '42'))
random.seed(RNG_SEED)
np.random.seed(RNG_SEED)
# Out:
# Torch available: 2.10.0+cu128
# CUDA available: True
# CUDA device: NVIDIA GeForce RTX 4090

# %%
def find_project_root() -> Path:
    cur = Path.cwd().resolve()
    for p in [cur, *cur.parents]:
        if (p / 'DATA').exists() and (p / 'new_data').exists():
            return p
    return Path.cwd().resolve()

ROOT = find_project_root()
DATA_DIR = ROOT / 'DATA'
SOKE_DATA = DATA_DIR / 'SOKE_DATA'

CSL_ROOT = SOKE_DATA / 'CSL-Daily-Fittings'
CSL_POSE_ROOT = CSL_ROOT / 'csl-daily_pose' / 'csl-daily_pose'
PHOENIX_ROOT = SOKE_DATA / 'phoenix_poses'
NSA_ROOT = SOKE_DATA / 'Neural-Sign-Actors'

NOTEBOOK_NAME = '01_csl_phoenix_neural_sign_actors_exploration_and_stats'
ARTIFACT_DIR = ROOT / 'new_data' / NOTEBOOK_NAME
PLOT_DIR = ARTIFACT_DIR / 'plots'
for d in [ARTIFACT_DIR, PLOT_DIR]:
    d.mkdir(parents=True, exist_ok=True)

MAX_CLIPS_PER_SPLIT_TEXT = os.environ.get('NEW_DATA_MAX_CLIPS_PER_SPLIT', '').strip()
MAX_CLIPS_PER_SPLIT = int(MAX_CLIPS_PER_SPLIT_TEXT) if MAX_CLIPS_PER_SPLIT_TEXT else None
RUN_RENDER = os.environ.get('NEW_DATA_RUN_RENDER', '0') == '1'
SAMPLE_SIZE = int(os.environ.get('NEW_DATA_SAMPLE_SIZE', '10'))

print('ROOT:', ROOT)
print('SOKE_DATA:', SOKE_DATA, '| exists:', SOKE_DATA.exists())
for label, path in [('CSL_ROOT', CSL_ROOT), ('CSL_POSE_ROOT', CSL_POSE_ROOT), ('PHOENIX_ROOT', PHOENIX_ROOT), ('NSA_ROOT', NSA_ROOT)]:
    print(f'{label}: {path} | exists={path.exists()}')
print('ARTIFACT_DIR:', ARTIFACT_DIR)
print('MAX_CLIPS_PER_SPLIT:', MAX_CLIPS_PER_SPLIT)
print('RUN_RENDER:', RUN_RENDER)
# Out:
# ROOT: /home/cem/tez/exp
# SOKE_DATA: /home/cem/tez/exp/DATA/SOKE_DATA | exists: True
# CSL_ROOT: /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fittings | exists=True
# CSL_POSE_ROOT: /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fittings/csl-daily_pose/csl-daily_pose | exists=True
# PHOENIX_ROOT: /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses | exists=True
# NSA_ROOT: /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-Actors | exists=True
# ARTIFACT_DIR: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats
# MAX_CLIPS_PER_SPLIT: 25
# RUN_RENDER: False

# %%
def _to_numpy(x):
    if TORCH_AVAILABLE:
        import torch
        if isinstance(x, torch.Tensor):
            return x.detach().cpu().numpy()
    if isinstance(x, np.ndarray):
        return x
    return x


def load_pickle_or_torch(path: Path):
    path = Path(path)
    if TORCH_AVAILABLE:
        try:
            return torch.load(path, map_location='cpu', weights_only=False)
        except Exception:
            pass
    with path.open('rb') as f:
        return pickle.load(f)


def load_gzip_pickle(path: Path):
    with gzip.open(path, 'rb') as f:
        return pickle.load(f)


def count_matching_files(dir_path: Path, suffix: str = '.pkl') -> int:
    try:
        with os.scandir(dir_path) as it:
            return sum(1 for e in it if e.is_file() and e.name.endswith(suffix))
    except FileNotFoundError:
        return 0


def list_clip_dirs(root: Path) -> list[Path]:
    if not root.exists():
        return []
    return sorted([p for p in root.iterdir() if p.is_dir()])


def maybe_limit_dirs(dirs: list[Path], split: str) -> list[Path]:
    if MAX_CLIPS_PER_SPLIT is None or len(dirs) <= MAX_CLIPS_PER_SPLIT:
        return dirs
    rng = random.Random(RNG_SEED + abs(hash(split)) % 100000)
    return sorted(rng.sample(dirs, MAX_CLIPS_PER_SPLIT))


def safe_len(value):
    if value is None or (isinstance(value, float) and np.isnan(value)):
        return 0
    if isinstance(value, (list, tuple, set)):
        return len(value)
    return len(str(value).split())


def describe_frame_schema(path: Path) -> dict:
    obj = load_pickle_or_torch(path)
    row = {'path': str(path), 'type': type(obj).__name__}
    if isinstance(obj, dict):
        row['keys'] = ', '.join(map(str, obj.keys()))
        for k, v in obj.items():
            v = _to_numpy(v)
            shape = tuple(np.shape(v)) if hasattr(v, 'shape') or isinstance(v, (list, tuple)) else None
            dtype = str(getattr(v, 'dtype', '')) if hasattr(v, 'dtype') else ''
            row[f'{k}_shape'] = shape
            row[f'{k}_dtype'] = dtype
    else:
        row['repr'] = repr(obj)[:200]
        row['shape'] = tuple(np.shape(obj)) if hasattr(obj, 'shape') else None
    return row

# %% [markdown]
# ## CSL-Daily Fittings
#
# The CSL split metadata files are gzip-compressed pickle lists. Each item has keys like `name`, `signer`, `gloss`, `text`, `sign`, and `num_frames`. Pose frames live under `csl-daily_pose/csl-daily_pose/<name>/*.pkl`.

# %%
def load_csl_split(split: str) -> pd.DataFrame:
    fp = CSL_ROOT / f'csl_clean.{split}'
    rows = load_gzip_pickle(fp)
    df = pd.DataFrame(rows)
    df['dataset'] = 'CSL-Daily-Fittings'
    df['split'] = 'val' if split == 'val' else split
    df['clip_id'] = df['name'].astype(str)
    df['pose_dir'] = df['clip_id'].map(lambda x: str(CSL_POSE_ROOT / x))
    df['pose_exists'] = df['pose_dir'].map(lambda x: Path(x).exists())
    df['metadata_num_frames'] = pd.to_numeric(df.get('num_frames'), errors='coerce')
    df['frame_pkls'] = [count_matching_files(Path(p), '.pkl') for p in df['pose_dir']]
    df['gloss_tokens'] = df.get('gloss', '').map(safe_len)
    df['text_tokens'] = df.get('text', '').map(safe_len)
    df['sign_tokens'] = df.get('sign', '').map(safe_len)
    df['scan_limited'] = False
    return df

csl_frames = []
for split in ['train', 'val', 'test']:
    df = load_csl_split(split)
    if MAX_CLIPS_PER_SPLIT is not None and len(df) > MAX_CLIPS_PER_SPLIT:
        df = df.sample(MAX_CLIPS_PER_SPLIT, random_state=RNG_SEED).sort_values('clip_id').reset_index(drop=True)
        df['scan_limited'] = True
    csl_frames.append(df)

csl_df = pd.concat(csl_frames, ignore_index=True)
print('CSL rows in this scan:', len(csl_df), '| limited:', bool(csl_df['scan_limited'].any()))
display(csl_df.head())

csl_split_stats = (
    csl_df.groupby(['dataset', 'split'])
    .agg(
        clips=('clip_id', 'nunique'),
        pose_dirs_found=('pose_exists', 'sum'),
        frame_pkls_sum=('frame_pkls', 'sum'),
        metadata_frames_sum=('metadata_num_frames', 'sum'),
        frame_pkls_mean=('frame_pkls', 'mean'),
        frame_pkls_median=('frame_pkls', 'median'),
        frame_pkls_p95=('frame_pkls', lambda s: float(np.percentile(s, 95))),
        frame_pkls_max=('frame_pkls', 'max'),
        signer_count=('signer', 'nunique'),
        gloss_tokens_mean=('gloss_tokens', 'mean'),
        text_tokens_mean=('text_tokens', 'mean'),
    )
    .reset_index()
)
display(csl_split_stats.round(3))
# Out:
# CSL rows in this scan: 75 | limited: True
#                 name  signer                         gloss  \
# 0  S000269_P0004_T00       4                天 2 小 累 跑步 去 不
# 1  S001023_P0000_T00       0                听 人 学 手语 一样 可以
# 2  S001638_P0005_T00       5                 手 2 吸烟 是 癌 重要
# 3  S001640_P0000_T00       0             癌 是 病 病 病 你们 心跳 不
# 4  S001723_P0004_T00       4  这 公司 有 免费 找 网络 手机 流量 有 多少 服务
#
#                     text            sign  num_frames             dataset  \
# 0         这两天有点儿累，不去跑步了。  [[tensor(0.)]]         156  CSL-Daily-Fittings
# 1             听人也可以学习手语。  [[tensor(0.)]]          87  CSL-Daily-Fittings
# 2          二手烟是癌症的重要污染源。  [[tensor(0.)]]         103  CSL-Daily-Fittings
# 3     癌症只是一种疾病，大家不要过于恐慌。  [[tensor(0.)]]         130  CSL-Daily-Fittings
# 4  这家公司提供了免费的话费流量套餐查询服务。  [[tensor(0.)]]         178  CSL-Daily-Fittings
#
#    split            clip_id  \
# 0  train  S000269_P0004_T00
# 1  train  S001023_P0000_T00
# 2  train  S001638_P0005_T00
# 3  train  S001640_P0000_T00
# 4  train  S001723_P0004_T00
#
#                                             pose_dir  pose_exists  \
# 0  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...         True
# 1  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...         True
# 2  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...         True
# 3  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...         True
# 4  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...         True
#
#    metadata_num_frames  frame_pkls  gloss_tokens  text_tokens  sign_tokens  \
# 0                  156         156             7            1            1
# 1                   87          87             6            1            1
# 2                  103         103             6            1            1
# 3                  130         130             8            1            1
# 4                  178         178            11            1            1
#
#    scan_limited
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#               dataset  split  clips  pose_dirs_found  frame_pkls_sum  \
# 0  CSL-Daily-Fittings   test     25               25            3187
# 1  CSL-Daily-Fittings  train     25               25            3005
# 2  CSL-Daily-Fittings    val     25               25            2999
#
#    metadata_frames_sum  frame_pkls_mean  frame_pkls_median  frame_pkls_p95  \
# 0                 3187           127.48              118.0           211.6
# 1                 3128           120.20              108.0           175.6
# 2                 3001           119.96              115.0           204.0
#
#    frame_pkls_max  signer_count  gloss_tokens_mean  text_tokens_mean
# 0             222            10               7.88               1.0
# 1             184             8               7.76               1.0
# 2             223             7               7.60               1.0

# %% [markdown]
# ## PHOENIX Pose Folders
#
# PHOENIX is organized as `phoenix_poses/<split>/<clip_id>/imagesNNNN.pkl`. Each frame pickle contains SMPL-X pose keys plus 2D projected joints and hand/face boxes.

# %%
def scan_phoenix() -> pd.DataFrame:
    rows = []
    for split in ['train', 'dev', 'test']:
        split_root = PHOENIX_ROOT / split
        clip_dirs = maybe_limit_dirs(list_clip_dirs(split_root), f'phoenix_{split}')
        for clip_dir in clip_dirs:
            rows.append({
                'dataset': 'PHOENIX',
                'split': split,
                'clip_id': clip_dir.name,
                'pose_dir': str(clip_dir),
                'pose_exists': clip_dir.exists(),
                'frame_pkls': count_matching_files(clip_dir, '.pkl'),
                'scan_limited': MAX_CLIPS_PER_SPLIT is not None and len(list_clip_dirs(split_root)) > len(clip_dirs),
            })
    return pd.DataFrame(rows)

phoenix_df = scan_phoenix()
print('PHOENIX rows in this scan:', len(phoenix_df), '| limited:', bool(phoenix_df['scan_limited'].any()) if len(phoenix_df) else False)
display(phoenix_df.head())

phoenix_split_stats = (
    phoenix_df.groupby(['dataset', 'split'])
    .agg(
        clips=('clip_id', 'nunique'),
        frame_pkls_sum=('frame_pkls', 'sum'),
        frame_pkls_mean=('frame_pkls', 'mean'),
        frame_pkls_median=('frame_pkls', 'median'),
        frame_pkls_p95=('frame_pkls', lambda s: float(np.percentile(s, 95))),
        frame_pkls_max=('frame_pkls', 'max'),
    )
    .reset_index()
)
display(phoenix_split_stats.round(3))
# Out:
# PHOENIX rows in this scan: 75 | limited: True
#    dataset  split                                    clip_id  \
# 0  PHOENIX  train   01December_2011_Thursday_tagesschau-3476
# 1  PHOENIX  train  03November_2010_Wednesday_tagesschau-6498
# 2  PHOENIX  train   03October_2012_Wednesday_tagesschau-7665
# 3  PHOENIX  train      04August_2011_Thursday_tagesschau-710
# 4  PHOENIX  train           04October_2010_Monday_heute-5948
#
#                                             pose_dir  pose_exists  frame_pkls  \
# 0  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...         True         153
# 1  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...         True          92
# 2  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...         True          63
# 3  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...         True         149
# 4  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...         True         369
#
#    scan_limited
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#    dataset  split  clips  frame_pkls_sum  frame_pkls_mean  frame_pkls_median  \
# 0  PHOENIX    dev     25            2527           101.08               98.0
# 1  PHOENIX   test     25            2194            87.76               87.0
# 2  PHOENIX  train     25            3351           134.04              139.0
#
#    frame_pkls_p95  frame_pkls_max
# 0           169.2             187
# 1           153.8             161
# 2           210.8             369

# %% [markdown]
# ## Neural Sign Actors Pose Folders
#
# Neural Sign Actors is organized as `<split>_poses/poses/<clip_id>/<clip_id>_<frame>_3D.pkl`. Each frame pickle contains the same SMPL-X pose key family as CSL, without PHOENIX's 2D projection/bbox keys.

# %%
def scan_neural_sign_actors() -> pd.DataFrame:
    split_map = {'train': 'train_poses', 'val': 'val_poses', 'test': 'test_poses'}
    rows = []
    for split, folder in split_map.items():
        split_root = NSA_ROOT / folder / 'poses'
        all_dirs = list_clip_dirs(split_root)
        clip_dirs = maybe_limit_dirs(all_dirs, f'nsa_{split}')
        for clip_dir in clip_dirs:
            rows.append({
                'dataset': 'Neural-Sign-Actors',
                'split': split,
                'clip_id': clip_dir.name,
                'pose_dir': str(clip_dir),
                'pose_exists': clip_dir.exists(),
                'frame_pkls': count_matching_files(clip_dir, '.pkl'),
                'scan_limited': MAX_CLIPS_PER_SPLIT is not None and len(all_dirs) > len(clip_dirs),
            })
    return pd.DataFrame(rows)

nsa_df = scan_neural_sign_actors()
print('Neural Sign Actors rows in this scan:', len(nsa_df), '| limited:', bool(nsa_df['scan_limited'].any()) if len(nsa_df) else False)
display(nsa_df.head())

nsa_split_stats = (
    nsa_df.groupby(['dataset', 'split'])
    .agg(
        clips=('clip_id', 'nunique'),
        frame_pkls_sum=('frame_pkls', 'sum'),
        frame_pkls_mean=('frame_pkls', 'mean'),
        frame_pkls_median=('frame_pkls', 'median'),
        frame_pkls_p95=('frame_pkls', lambda s: float(np.percentile(s, 95))),
        frame_pkls_max=('frame_pkls', 'max'),
    )
    .reset_index()
)
display(nsa_split_stats.round(3))
# Out:
# Neural Sign Actors rows in this scan: 75 | limited: True
#               dataset  split                     clip_id  \
# 0  Neural-Sign-Actors  train  02WRxAwx-Bo_10-8-rgb_front
# 1  Neural-Sign-Actors  train  06St8W_JHok_22-5-rgb_front
# 2  Neural-Sign-Actors  train   0ICZi26jdaQ_1-5-rgb_front
# 3  Neural-Sign-Actors  train   0sff0qsiAbw_6-8-rgb_front
# 4  Neural-Sign-Actors  train  0wPJGhjnX-s_14-8-rgb_front
#
#                                             pose_dir  pose_exists  frame_pkls  \
# 0  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...         True          40
# 1  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...         True          83
# 2  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...         True         121
# 3  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...         True         108
# 4  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...         True          86
#
#    scan_limited
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#               dataset  split  clips  frame_pkls_sum  frame_pkls_mean  \
# 0  Neural-Sign-Actors   test     25            3207           128.28
# 1  Neural-Sign-Actors  train     25            3840           153.60
# 2  Neural-Sign-Actors    val     25            3908           156.32
#
#    frame_pkls_median  frame_pkls_p95  frame_pkls_max
# 0              125.0           295.8             359
# 1              126.0           334.4             433
# 2              133.0           295.6             418

# %% [markdown]
# ## Combined Split Statistics

# %%
common_cols = ['dataset', 'split', 'clip_id', 'pose_dir', 'pose_exists', 'frame_pkls', 'scan_limited']
combined_df = pd.concat([
    csl_df[common_cols + ['metadata_num_frames', 'gloss_tokens', 'text_tokens', 'signer']].rename(columns={'metadata_num_frames': 'metadata_frames'}),
    phoenix_df[common_cols].assign(metadata_frames=np.nan, gloss_tokens=np.nan, text_tokens=np.nan, signer=np.nan),
    nsa_df[common_cols].assign(metadata_frames=np.nan, gloss_tokens=np.nan, text_tokens=np.nan, signer=np.nan),
], ignore_index=True)

combined_stats = (
    combined_df.groupby(['dataset', 'split'])
    .agg(
        clips=('clip_id', 'nunique'),
        pose_dirs_found=('pose_exists', 'sum'),
        frame_pkls_sum=('frame_pkls', 'sum'),
        frame_pkls_mean=('frame_pkls', 'mean'),
        frame_pkls_median=('frame_pkls', 'median'),
        frame_pkls_p95=('frame_pkls', lambda s: float(np.percentile(s, 95))),
        frame_pkls_max=('frame_pkls', 'max'),
        scan_limited=('scan_limited', 'max'),
    )
    .reset_index()
)

display(combined_stats.round(3))

summary_csv = ARTIFACT_DIR / 'combined_split_stats.csv'
clip_index_csv = ARTIFACT_DIR / 'combined_clip_index.csv'
combined_stats.to_csv(summary_csv, index=False)
combined_df.to_csv(clip_index_csv, index=False)
print('Wrote:', summary_csv)
print('Wrote:', clip_index_csv)
# Out:
#               dataset  split  clips  pose_dirs_found  frame_pkls_sum  \
# 0  CSL-Daily-Fittings   test     25               25            3187
# 1  CSL-Daily-Fittings  train     25               25            3005
# 2  CSL-Daily-Fittings    val     25               25            2999
# 3  Neural-Sign-Actors   test     25               25            3207
# 4  Neural-Sign-Actors  train     25               25            3840
# 5  Neural-Sign-Actors    val     25               25            3908
# 6             PHOENIX    dev     25               25            2527
# 7             PHOENIX   test     25               25            2194
# 8             PHOENIX  train     25               25            3351
#
#    frame_pkls_mean  frame_pkls_median  frame_pkls_p95  frame_pkls_max  \
# 0           127.48              118.0           211.6             222
# 1           120.20              108.0           175.6             184
# 2           119.96              115.0           204.0             223
# 3           128.28              125.0           295.8             359
# 4           153.60              126.0           334.4             433
# 5           156.32              133.0           295.6             418
# 6           101.08               98.0           169.2             187
# 7            87.76               87.0           153.8             161
# 8           134.04              139.0           210.8             369
#
#    scan_limited
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# Wrote: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/combined_split_stats.csv
# Wrote: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/combined_clip_index.csv

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4.5))

plot_df = combined_df[combined_df['frame_pkls'] > 0].copy()
for dataset in plot_df['dataset'].dropna().unique():
    vals = plot_df.loc[plot_df['dataset'] == dataset, 'frame_pkls'].values
    axes[0].hist(vals, bins=60, alpha=0.45, label=dataset)
axes[0].set_title('Frame Count Distribution By Dataset (lower/shorter vs higher/longer)')
axes[0].set_xlabel('Frame PKLs per clip')
axes[0].set_ylabel('Clips')
axes[0].legend()

bar_df = combined_stats.copy()
bar_df['label'] = bar_df['dataset'] + ' / ' + bar_df['split']
axes[1].barh(bar_df['label'], bar_df['frame_pkls_sum'])
axes[1].set_title('Total Frame PKLs By Split (higher means more data)')
axes[1].set_xlabel('Frame PKLs')
axes[1].set_ylabel('Dataset / split')

fig.tight_layout()
plot_path = PLOT_DIR / 'frame_count_stats.png'
fig.savefig(plot_path, dpi=150, bbox_inches='tight')
print('Wrote:', plot_path)
plt.show()
# Out:
# Wrote: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/plots/frame_count_stats.png

# %% [markdown]
# ## Random Sample Records And Pose Schemas

# %%
sample_rows = []
schema_rows = []

for dataset, df in [('CSL-Daily-Fittings', csl_df), ('PHOENIX', phoenix_df), ('Neural-Sign-Actors', nsa_df)]:
    if len(df) == 0:
        continue
    n = min(SAMPLE_SIZE, len(df))
    sample_df = df.sample(n, random_state=RNG_SEED).copy().reset_index(drop=True)
    for _, row in sample_df.iterrows():
        pose_dir = Path(row['pose_dir'])
        frame_files = sorted(pose_dir.glob('*.pkl'))
        first_frame = frame_files[0] if frame_files else None
        sample_rows.append({
            'dataset': dataset,
            'split': row.get('split'),
            'clip_id': row.get('clip_id'),
            'frame_pkls': int(row.get('frame_pkls', 0)),
            'pose_dir': str(pose_dir),
            'first_frame_pkl': str(first_frame) if first_frame else '',
        })
        if first_frame is not None:
            try:
                schema = describe_frame_schema(first_frame)
                schema['dataset'] = dataset
                schema['split'] = row.get('split')
                schema['clip_id'] = row.get('clip_id')
                schema_rows.append(schema)
            except Exception as e:
                warnings.warn(f'Failed schema load for {first_frame}: {e}')

sample_df = pd.DataFrame(sample_rows)
schema_df = pd.DataFrame(schema_rows)

display(sample_df)
display(schema_df)

sample_csv = ARTIFACT_DIR / 'random_sample_records.csv'
schema_csv = ARTIFACT_DIR / 'sample_pose_schema.csv'
sample_df.to_csv(sample_csv, index=False)
schema_df.to_csv(schema_csv, index=False)
print('Wrote:', sample_csv)
print('Wrote:', schema_csv)
# Out:
#                dataset  split                                    clip_id  \
# 0   CSL-Daily-Fittings  train                          S001723_P0004_T00
# 1   CSL-Daily-Fittings   test                          S002210_P0007_T00
# 2   CSL-Daily-Fittings  train                          S003397_P0002_T00
# 3   CSL-Daily-Fittings  train                          S000269_P0004_T00
# 4   CSL-Daily-Fittings    val                          S003933_P0000_T00
# 5   CSL-Daily-Fittings   test                          S002164_P0000_T00
# 6   CSL-Daily-Fittings    val                          S002504_P0000_T00
# 7   CSL-Daily-Fittings  train                          S003544_P0002_T00
# 8   CSL-Daily-Fittings   test                          S005248_P0009_T00
# 9   CSL-Daily-Fittings   test                          S002256_P0005_T00
# 10             PHOENIX  train           04October_2010_Monday_heute-5948
# 11             PHOENIX   test  16December_2009_Wednesday_tagesschau-5913
# 12             PHOENIX  train     09November_2010_Tuesday_tagesschau-752
# 13             PHOENIX  train   01December_2011_Thursday_tagesschau-3476
# 14             PHOENIX    dev     20October_2009_Tuesday_tagesschau-3586
# 15             PHOENIX   test         13July_2009_Monday_tagesschau-7508
# 16             PHOENIX    dev    06October_2012_Saturday_tagesschau-8744
# 17             PHOENIX  train      11August_2009_Tuesday_tagesschau-4361
# 18             PHOENIX   test      24March_2011_Thursday_tagesschau-3938
# 19             PHOENIX   test      17January_2011_Monday_tagesschau-7005
# 20  Neural-Sign-Actors  train                 0wPJGhjnX-s_14-8-rgb_front
# 21  Neural-Sign-Actors   test                 G3di9jJTqDs_7-10-rgb_front
# 22  Neural-Sign-Actors  train                  1aRcg_P7Vow_3-8-rgb_front
# 23  Neural-Sign-Actors  train                 02WRxAwx-Bo_10-8-rgb_front
# 24  Neural-Sign-Actors    val                 DfnHNkTE7mE_18-5-rgb_front
# 25  Neural-Sign-Actors   test                 G3GcPpidwxk_16-5-rgb_front
# 26  Neural-Sign-Actors    val                  33jxeIIbBnM_1-1-rgb_front
# 27  Neural-Sign-Actors  train                  1dLchY8R6tU_7-8-rgb_front
# 28  Neural-Sign-Actors   test                  fzQ2E3_xBZA_1-8-rgb_front
# 29  Neural-Sign-Actors   test                  G3gm_C5UueQ_8-5-rgb_front
#
#     frame_pkls                                           pose_dir  \
# 0          178  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 1          222  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 2          161  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 3          156  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 4           87  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 5          141  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 6          133  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 7           89  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 8          108  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 9          150  /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 10         369  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 11          78  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 12         141  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 13         153  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 14         120  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 15         153  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 16          70  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 17          70  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 18          56  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 19         130  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 20          86  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 21          33  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 22         241  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 23          40  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 24          63  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 25         131  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 26          75  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 27          58  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 28          38  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 29          96  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
#
#                                       first_frame_pkl
# 0   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 1   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 2   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 3   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 4   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 5   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 6   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 7   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 8   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 9   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...
# 10  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 11  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 12  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 13  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 14  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 15  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 16  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 17  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 18  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 19  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...
# 20  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 21  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 22  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 23  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 24  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 25  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 26  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 27  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 28  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
# 29  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...
#                                                  path  type  \
# 0   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 1   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 2   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 3   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 4   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 5   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 6   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 7   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 8   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 9   /home/cem/tez/exp/DATA/SOKE_DATA/CSL-Daily-Fit...  dict
# 10  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 11  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 12  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 13  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 14  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 15  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 16  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 17  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 18  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 19  /home/cem/tez/exp/DATA/SOKE_DATA/phoenix_poses...  dict
# 20  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 21  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 22  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 23  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 24  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 25  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 26  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 27  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 28  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
# 29  /home/cem/tez/exp/DATA/SOKE_DATA/Neural-Sign-A...  dict
#
#                                                  keys smplx_root_pose_shape  \
# 0   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 1   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 2   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 3   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 4   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 5   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 6   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 7   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 8   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 9   smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 10  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 11  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 12  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 13  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 14  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 15  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 16  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 17  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 18  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 19  smplx_joint_proj, smplx_root_pose, smplx_body_...                  (3,)
# 20  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 21  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 22  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 23  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 24  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 25  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 26  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 27  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 28  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
# 29  smplx_root_pose, smplx_body_pose, smplx_lhand_...                  (3,)
#
#    smplx_root_pose_dtype smplx_body_pose_shape smplx_body_pose_dtype  \
# 0                float32                 (63,)               float32
# 1                float32                 (63,)               float32
# 2                float32                 (63,)               float32
# 3                float32                 (63,)               float32
# 4                float32                 (63,)               float32
# 5                float32                 (63,)               float32
# 6                float32                 (63,)               float32
# 7                float32                 (63,)               float32
# 8                float32                 (63,)               float32
# 9                float32                 (63,)               float32
# 10               float32                 (63,)               float32
# 11               float32                 (63,)               float32
# 12               float32                 (63,)               float32
# 13               float32                 (63,)               float32
# 14               float32                 (63,)               float32
# 15               float32                 (63,)               float32
# 16               float32                 (63,)               float32
# 17               float32                 (63,)               float32
# 18               float32                 (63,)               float32
# 19               float32                 (63,)               float32
# 20               float32                 (63,)               float32
# 21               float32                 (63,)               float32
# 22               float32                 (63,)               float32
# 23               float32                 (63,)               float32
# 24               float32                 (63,)               float32
# 25               float32                 (63,)               float32
# 26               float32                 (63,)               float32
# 27               float32                 (63,)               float32
# 28               float32                 (63,)               float32
# 29               float32                 (63,)               float32
#
#    smplx_lhand_pose_shape smplx_lhand_pose_dtype smplx_rhand_pose_shape  ...  \
# 0                   (45,)                float32                  (45,)  ...
# 1                   (45,)                float32                  (45,)  ...
# 2                   (45,)                float32                  (45,)  ...
# 3                   (45,)                float32                  (45,)  ...
# 4                   (45,)                float32                  (45,)  ...
# 5                   (45,)                float32                  (45,)  ...
# 6                   (45,)                float32                  (45,)  ...
# 7                   (45,)                float32                  (45,)  ...
# 8                   (45,)                float32                  (45,)  ...
# 9                   (45,)                float32                  (45,)  ...
# 10                  (45,)                float32                  (45,)  ...
# 11                  (45,)                float32                  (45,)  ...
# 12                  (45,)                float32                  (45,)  ...
# 13                  (45,)                float32                  (45,)  ...
# 14                  (45,)                float32                  (45,)  ...
# 15                  (45,)                float32                  (45,)  ...
# 16                  (45,)                float32                  (45,)  ...
# 17                  (45,)                float32                  (45,)  ...
# 18                  (45,)                float32                  (45,)  ...
# 19                  (45,)                float32                  (45,)  ...
# 20                  (45,)                float32                  (45,)  ...
# 21                  (45,)                float32                  (45,)  ...
# 22                  (45,)                float32                  (45,)  ...
# 23                  (45,)                float32                  (45,)  ...
# 24                  (45,)                float32                  (45,)  ...
# 25                  (45,)                float32                  (45,)  ...
# 26                  (45,)                float32                  (45,)  ...
# 27                  (45,)                float32                  (45,)  ...
# 28                  (45,)                float32                  (45,)  ...
# 29                  (45,)                float32                  (45,)  ...
#
#     split                                    clip_id smplx_joint_proj_shape  \
# 0   train                          S001723_P0004_T00                    NaN
# 1    test                          S002210_P0007_T00                    NaN
# 2   train                          S003397_P0002_T00                    NaN
# 3   train                          S000269_P0004_T00                    NaN
# 4     val                          S003933_P0000_T00                    NaN
# 5    test                          S002164_P0000_T00                    NaN
# 6     val                          S002504_P0000_T00                    NaN
# 7   train                          S003544_P0002_T00                    NaN
# 8    test                          S005248_P0009_T00                    NaN
# 9    test                          S002256_P0005_T00                    NaN
# 10  train           04October_2010_Monday_heute-5948               (137, 2)
# 11   test  16December_2009_Wednesday_tagesschau-5913               (137, 2)
# 12  train     09November_2010_Tuesday_tagesschau-752               (137, 2)
# 13  train   01December_2011_Thursday_tagesschau-3476               (137, 2)
# 14    dev     20October_2009_Tuesday_tagesschau-3586               (137, 2)
# 15   test         13July_2009_Monday_tagesschau-7508               (137, 2)
# 16    dev    06October_2012_Saturday_tagesschau-8744               (137, 2)
# 17  train      11August_2009_Tuesday_tagesschau-4361               (137, 2)
# 18   test      24March_2011_Thursday_tagesschau-3938               (137, 2)
# 19   test      17January_2011_Monday_tagesschau-7005               (137, 2)
# 20  train                 0wPJGhjnX-s_14-8-rgb_front                    NaN
# 21   test                 G3di9jJTqDs_7-10-rgb_front                    NaN
# 22  train                  1aRcg_P7Vow_3-8-rgb_front                    NaN
# 23  train                 02WRxAwx-Bo_10-8-rgb_front                    NaN
# 24    val                 DfnHNkTE7mE_18-5-rgb_front                    NaN
# 25   test                 G3GcPpidwxk_16-5-rgb_front                    NaN
# 26    val                  33jxeIIbBnM_1-1-rgb_front                    NaN
# 27  train                  1dLchY8R6tU_7-8-rgb_front                    NaN
# 28   test                  fzQ2E3_xBZA_1-8-rgb_front                    NaN
# 29   test                  G3gm_C5UueQ_8-5-rgb_front                    NaN
#
#    smplx_joint_proj_dtype lhand_bbox_shape lhand_bbox_dtype rhand_bbox_shape  \
# 0                     NaN              NaN              NaN              NaN
# 1                     NaN              NaN              NaN              NaN
# 2                     NaN              NaN              NaN              NaN
# 3                     NaN              NaN              NaN              NaN
# 4                     NaN              NaN              NaN              NaN
# 5                     NaN              NaN              NaN              NaN
# 6                     NaN              NaN              NaN              NaN
# 7                     NaN              NaN              NaN              NaN
# 8                     NaN              NaN              NaN              NaN
# 9                     NaN              NaN              NaN              NaN
# 10                float32             (4,)          float32             (4,)
# 11                float32             (4,)          float32             (4,)
# 12                float32             (4,)          float32             (4,)
# 13                float32             (4,)          float32             (4,)
# 14                float32             (4,)          float32             (4,)
# 15                float32             (4,)          float32             (4,)
# 16                float32             (4,)          float32             (4,)
# 17                float32             (4,)          float32             (4,)
# 18                float32             (4,)          float32             (4,)
# 19                float32             (4,)          float32             (4,)
# 20                    NaN              NaN              NaN              NaN
# 21                    NaN              NaN              NaN              NaN
# 22                    NaN              NaN              NaN              NaN
# 23                    NaN              NaN              NaN              NaN
# 24                    NaN              NaN              NaN              NaN
# 25                    NaN              NaN              NaN              NaN
# 26                    NaN              NaN              NaN              NaN
# 27                    NaN              NaN              NaN              NaN
# 28                    NaN              NaN              NaN              NaN
# 29                    NaN              NaN              NaN              NaN
#
#    rhand_bbox_dtype face_bbox_shape face_bbox_dtype
# 0               NaN             NaN             NaN
# 1               NaN             NaN             NaN
# 2               NaN             NaN             NaN
# 3               NaN             NaN             NaN
# 4               NaN             NaN             NaN
# 5               NaN             NaN             NaN
# 6               NaN             NaN             NaN
# 7               NaN             NaN             NaN
# 8               NaN             NaN             NaN
# 9               NaN             NaN             NaN
# 10          float32            (4,)         float32
# 11          float32            (4,)         float32
# 12          float32            (4,)         float32
# 13          float32            (4,)         float32
# 14          float32            (4,)         float32
# 15          float32            (4,)         float32
# 16          float32            (4,)         float32
# 17          float32            (4,)         float32
# 18          float32            (4,)         float32
# 19          float32            (4,)         float32
# 20              NaN             NaN             NaN
# 21              NaN             NaN             NaN
# 22              NaN             NaN             NaN
# 23              NaN             NaN             NaN
# 24              NaN             NaN             NaN
# 25              NaN             NaN             NaN
# 26              NaN             NaN             NaN
# 27              NaN             NaN             NaN
# 28              NaN             NaN             NaN
# 29              NaN             NaN             NaN
#
# [30 rows x 30 columns]
# Wrote: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/random_sample_records.csv
# Wrote: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/sample_pose_schema.csv

# %% [markdown]
# ## CSL Text / Gloss Statistics

# %%
if len(csl_df):
    csl_text_stats = (
        csl_df.groupby('split')
        .agg(
            clips=('clip_id', 'nunique'),
            signers=('signer', 'nunique'),
            gloss_tokens_mean=('gloss_tokens', 'mean'),
            gloss_tokens_median=('gloss_tokens', 'median'),
            gloss_tokens_p95=('gloss_tokens', lambda s: float(np.percentile(s, 95))),
            text_tokens_mean=('text_tokens', 'mean'),
            text_tokens_median=('text_tokens', 'median'),
            sign_tokens_mean=('sign_tokens', 'mean'),
        )
        .reset_index()
    )
    display(csl_text_stats.round(3))
    csl_text_stats.to_csv(ARTIFACT_DIR / 'csl_text_gloss_stats.csv', index=False)

    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    for split, df in csl_df.groupby('split'):
        axes[0].hist(df['gloss_tokens'], bins=40, alpha=0.45, label=split)
        axes[1].hist(df['text_tokens'], bins=40, alpha=0.45, label=split)
    axes[0].set_title('CSL Gloss Token Counts (lower/shorter vs higher/longer)')
    axes[0].set_xlabel('Gloss tokens')
    axes[0].set_ylabel('Clips')
    axes[0].legend()
    axes[1].set_title('CSL Text Token Counts (lower/shorter vs higher/longer)')
    axes[1].set_xlabel('Text tokens')
    axes[1].set_ylabel('Clips')
    axes[1].legend()
    fig.tight_layout()
    out = PLOT_DIR / 'csl_text_gloss_distributions.png'
    fig.savefig(out, dpi=150, bbox_inches='tight')
    print('Wrote:', out)
    plt.show()
# Out:
#    split  clips  signers  gloss_tokens_mean  gloss_tokens_median  \
# 0   test     25       10               7.88                  8.0
# 1  train     25        8               7.76                  7.0
# 2    val     25        7               7.60                  7.0
#
#    gloss_tokens_p95  text_tokens_mean  text_tokens_median  sign_tokens_mean
# 0              13.6               1.0                 1.0               1.0
# 1              13.6               1.0                 1.0               1.0
# 2              12.4               1.0                 1.0               1.0
# Wrote: /home/cem/tez/exp/new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/plots/csl_text_gloss_distributions.png

# %% [markdown]
# ## Optional Mesh-Only Render Smoke Test
#
# This section is disabled by default because these SOKE_DATA folders contain pose frames but not local RGB clips in the same layout as How2Sign. Enable with `NEW_DATA_RUN_RENDER=1` to render one mesh-only clip per dataset when `smplx_gif_renderer.py`, body models, and CUDA are available.

# %%
def stack_smplx_frames(frame_files: list[Path]) -> np.ndarray:
    rows = []
    for fp in frame_files:
        obj = load_pickle_or_torch(fp)
        if not isinstance(obj, dict):
            continue
        rows.append(np.concatenate([
            np.asarray(obj['smplx_root_pose'], dtype=np.float32).reshape(-1),
            np.asarray(obj['smplx_body_pose'], dtype=np.float32).reshape(-1),
            np.asarray(obj['smplx_lhand_pose'], dtype=np.float32).reshape(-1),
            np.asarray(obj['smplx_rhand_pose'], dtype=np.float32).reshape(-1),
            np.asarray(obj['smplx_jaw_pose'], dtype=np.float32).reshape(-1),
            np.asarray(obj['smplx_shape'], dtype=np.float32).reshape(-1),
            np.asarray(obj.get('smplx_expr', np.zeros(10, dtype=np.float32)), dtype=np.float32).reshape(-1),
            np.asarray(obj['cam_trans'], dtype=np.float32).reshape(-1),
        ]))
    if not rows:
        raise RuntimeError('No SMPL-X frames could be stacked.')
    return np.stack(rows, axis=0).astype(np.float32)

if RUN_RENDER:
    import torch
    from IPython.display import Video
    from smplx_gif_renderer import SMPLXGifRenderer

    if not torch.cuda.is_available():
        raise RuntimeError('NEW_DATA_RUN_RENDER=1 requires CUDA for this renderer path.')

    renderer = SMPLXGifRenderer(
        model_root=ROOT / 'body_models',
        require_gpu=True,
        output_size=(512, 512),
        camera_elev=6.0,
        camera_azim=-90.0,
        camera_zoom=0.62,
        default_max_render_frames=96,
        face_step=1,
    )
    render_dir = ARTIFACT_DIR / 'mesh_only_render_smoke'
    render_dir.mkdir(parents=True, exist_ok=True)
    for _, row in sample_df.drop_duplicates('dataset').iterrows():
        pose_dir = Path(row['pose_dir'])
        frame_files = sorted(pose_dir.glob('*.pkl'))[:96]
        motion = stack_smplx_frames(frame_files)
        out_mp4 = render_dir / f"{row['dataset']}__{row['clip_id']}__mesh.mp4".replace('/', '_')
        renderer.render_smplx_mp4(motion, out_mp4, show_skeleton=False, max_render_frames=96)
        display(Markdown(f"### {row['dataset']} / {row['clip_id']}"))
        display(Video(str(out_mp4), embed=True, html_attributes='controls'))
else:
    print('Optional render disabled. Set NEW_DATA_RUN_RENDER=1 to render mesh-only smoke clips.')
# Out:
# Optional render disabled. Set NEW_DATA_RUN_RENDER=1 to render mesh-only smoke clips.

# %% [markdown]
# ## Reproduction Notes
#
# Useful environment flags:
#
# - `NEW_DATA_MAX_CLIPS_PER_SPLIT=100` limits each split scan for fast smoke execution.
# - `NEW_DATA_SAMPLE_SIZE=10` controls random sample rows per dataset.
# - `NEW_DATA_RUN_RENDER=1` enables optional mesh-only SMPL-X rendering.
#
# Main artifacts are written to `new_data/01_csl_phoenix_neural_sign_actors_exploration_and_stats/`.
